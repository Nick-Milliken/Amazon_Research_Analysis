# %%
#required for creating datasets for sql in python
#only need run once
# !pip install opendatasets

# %%
#required to use sql in python
#only need run once
# !pip install ipython-sql

# %%
#imports
import pandas as pd
import numpy as np
import requests
import opendatasets as od
import sqlite3
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression
print('imports complete')
# Out:
# imports complete

# %%
train_data = pd.read_csv('train_ctrUa4K.csv')
train_df = pd.DataFrame(train_data)
train_df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
conn = sqlite3.connect('train_df.db')
train_df.to_sql('train_data_table',conn)
print("sql database and table complete")
#do not run again less you want to see errors

# %%
# %load_ext sql
print("sql loaded")
#do not run again less you want to see errors
# Out:
# sql loaded

# %%
# %sql sqlite:///train_df.db
print("database active")
#need only run once
# Out:
# database active

# %% [markdown]
# ### Note, %%sql can be the only thing in the cell or it will through an error

# %% [markdown]
# ## Test to see if table is correct

# %%
# %%sql
#
# SELECT Property_Area FROM train_data_table where Married == 'Yes' Group By Gender LIMIT 10;
# Out:
#  * sqlite:///train_df.db
# Done.
# [('Rural',), ('Semiurban',), ('Rural',)]

# %%
train_df['gender_label'] = train_df.groupby(pd.Grouper(key='Gender')).ngroup()
#confirm label
print(train_df.head())


#create function to label key feature column
def label(DF,label):
        Y = df_train.groupby(["label"]).get_group(label)
        Input = pd.DataFrame(Y)
        pd.DataFrame(Input)
        return Input

#no model built yet but will use later
#model = our model 

#create differetn dataframes for each label created to run model(s) on for more precision 
def w(arg):
    for i in range(0,336):
        W = label(arg, i)
        W = pd.DataFrame(W)
        pd.DataFrame(W)
        print(W)
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status  gender_label
# 0             1.0         Urban           Y             0
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
train_df = train_df.dropna()

# %%
train_df['Loan_Status'] = train_df['Loan_Status'].replace({'Y':1,'N':0})
train_df.head()
# Out:
# C:\Users\nmill\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
# 5  LP001011   Male     Yes          2      Graduate           Yes
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 1             4583             1508.0       128.0             360.0
# ...

# %%
Property_Area = {'Urban':3, 'SemiUrban':2, 'Rural':1}
label_encoder = LabelEncoder()
train_df['Property_Area'] = label_encoder.fit_transform(train_df['Property_Area'])
train_df.head()
# Out:
# C:\Users\nmill\anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
# 5  LP001011   Male     Yes          2      Graduate           Yes
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
#create features and shape data 
new_df = pd.DataFrame({'Property_Area':train_df.Property_Area, 'Credit_History':train_df.Credit_History, 'Loan_Status':train_df.Loan_Status})
features = ['Credit_History', 'Property_Area']

X = new_df[features]
y = new_df.Loan_Status

# %%
X
# Out:
#      Credit_History  Property_Area
# 1               1.0              0
# 2               1.0              2
# 3               1.0              2
# 4               1.0              2
# 5               1.0              2
# ..              ...            ...
# 609             1.0              0
# 610             1.0              0
# 611             1.0              2
# 612             1.0              2
# 613             0.0              1
#
# [480 rows x 2 columns]

# %%
new_df.head()
# Out:
#    Property_Area  Credit_History  Loan_Status
# 1              0             1.0            0
# 2              2             1.0            1
# 3              2             1.0            1
# 4              2             1.0            1
# 5              2             1.0            1

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

#X = np.array([X]).reshape(-1,1)
#y = np.array([y]).reshape(1,-1)

model = LogisticRegression().fit(X,y)

r_sq = model.score(X,y)
r_sq
# Out:
# 0.8083333333333333
